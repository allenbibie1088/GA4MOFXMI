# %%
#Author: Habibi Husain Arifin
#Created Date: 26 December 2018
#Last Updated Date: 26 December 2018
#Version: 1.0
#<a rel="license" href="http://creativecommons.org/licenses/by-sa/4.0/"><img alt="Creative Commons License" style="border-width:0" src="https://i.creativecommons.org/l/by-sa/4.0/88x31.png" /></a><br />This work is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by-sa/4.0/">Creative Commons Attribution-ShareAlike 4.0 International License</a>.

import matplotlib.pyplot as plt
import networkx as nx
import pydot

#nodes = [1, 2]
#edges = [(3,4),(1,4)]

#nodes, edges, labels = gp.graph(objs)
graph = nx.Graph()
graph.add_node(1,level=1)
graph.add_node(2,level=2)
graph.add_node(3,level=2)
graph.add_node(4,level=3)

graph.add_edge(1,2)
graph.add_edge(1,3)
graph.add_edge(2,4)
#graph.add_nodes_from(nodes)
#graph.add_edges_from(edges)
pos = nx.nx_pydot.graphviz_layout(graph, prog="dot")

plt.figure(figsize=(7,7))
nx.draw_networkx_nodes(graph, pos, node_size=900, node_color="b")
nx.draw_networkx_edges(graph, pos)
nx.draw_networkx_labels(graph, pos)
plt.axis("off")
plt.show()
